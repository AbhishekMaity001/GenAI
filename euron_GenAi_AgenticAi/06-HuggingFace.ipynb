# %%
import nltk
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Fri Jan  2 09:14:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 590.48.01              Driver Version: 591.59         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650        On  |   00000000:01:00.0  On |                  N/A |
# | N/A   55C    P8              2W /   50W |    2644MiB /   4096MiB |      6%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A              27      G   /Xwayland                             N/A      |
# |    0   N/A  N/A            6109      C   /python3.10                           N/A      |
# |    0   N/A  N/A           12319      C   /python3.10                           N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import transformers
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification

# %%
model_name = "distilbert/distilbert-base-uncased-finetuned-sst-2-english"


tokenizer = AutoTokenizer.from_pretrained(model_name)
model = TFAutoModelForSequenceClassification.from_pretrained(model_name, from_pt=True, use_safetensors=False)
# Out:
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading a PyTorch model in TensorFlow, requires both PyTorch and TensorFlow to be installed. Please see https://pytorch.org/ and https://www.tensorflow.org/install/ for installation instructions.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 5
#       1 model_name = "distilbert/distilbert-base-uncased-finetuned-sst-2-english"
#       4 tokenizer = AutoTokenizer.from_pretrained(model_name)
# ----> 5 model = TFAutoModelForSequenceClassification.from_pretrained(model_name, from_pt=True, use_safetensors=False)
#
# File ~/anaconda3/envs/tf-gpu/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:604, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602     if model_class.config_class == config.sub_configs.get("text_config", None):
#     603         config = config.get_text_config()
# --> 604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
#     607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# File ~/anaconda3/envs/tf-gpu/lib/python3.10/site-packages/transformers/modeling_tf_utils.py:2941, in TFPreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2938     from .modeling_tf_pytorch_utils import load_pytorch_checkpoint_in_tf2_model
#    2940     # Load from a PyTorch checkpoint
# -> 2941     return load_pytorch_checkpoint_in_tf2_model(
#    2942         model,
#    2943         resolved_archive_file,
#    2944         allow_missing_keys=True,
#    2945         output_loading_info=output_loading_info,
#    2946         _prefix=load_weight_prefix,
#    2947         tf_to_pt_weight_rename=tf_to_pt_weight_rename,
#    2948     )
#    2950 # we might need to extend the variable scope for composite models
#    2951 if load_weight_prefix is not None:
#
# File ~/anaconda3/envs/tf-gpu/lib/python3.10/site-packages/transformers/modeling_tf_pytorch_utils.py:184, in load_pytorch_checkpoint_in_tf2_model(tf_model, pytorch_checkpoint_path, tf_inputs, allow_missing_keys, output_loading_info, _prefix, tf_to_pt_weight_rename)
#     182 try:
#     183     import tensorflow as tf  # noqa: F401
# --> 184     import torch  # noqa: F401
#     185     from safetensors.torch import load_file as safe_load_file  # noqa: F401
#     186 except ImportError:
#
# ModuleNotFoundError: No module named 'torch'

# %%
text = "i love all the features provided by euron"
