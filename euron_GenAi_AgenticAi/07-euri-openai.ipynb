# %%
import tensorflow as tf

# %%
# !nvidia-smi
# Out:
# Fri Jan  2 17:32:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
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

# %%
import openai

# %%
openai.api_key = key

# %%
openai.completions.create(
    model="davinci-002",
    prompt = "write a poem about euri",
    temperature=0.2  # between 0-1, close to 0 means model will halocinate less
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipython-input-718541958.py in <cell line: 0>()
# ----> 1 openai.completions.create(
#       2     model="davinci-002",
#       3     prompt = "write a poem about euri",
#       4     temperature=0.2  # between 0-1, close to 0 means model will halocinate less
#       5 )
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     284                         msg = f"Missing required argument: {quote(missing[0])}"
#     285                 raise TypeError(msg)
# --> 286             return func(*args, **kwargs)
#     287
#     288         return wrapper  # type: ignore
#
# ...

# %%
openai.ChatCompletion.create(
    model="gpt.4.1-nano",
    messages = [
        {"role": "system", "content": "you are an experienced data scientist"},
        {"role": "user", "content": "give me a roadmap to become lead data scientist"}
    ],
    temperature=.4
)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# /tmp/ipython-input-1428909429.py in <cell line: 0>()
# ----> 1 openai.ChatCompletion.create(
#       2     model="gpt.4.1-nano",
#       3     messages = [
#       4         {"role": "system", "content": "you are an experienced data scientist"},
#       5         {"role": "user", "content": "give me a roadmap to become lead data scientist"}
#
# /usr/local/lib/python3.12/dist-packages/openai/lib/_old_api.py in __call__(self, *_args, **_kwargs)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# ...

# %%
# pip install openai==0.28

# %% [markdown]
# ## Euri

# %%
import requests

def generate_completion():
    url = "https://api.euron.one/api/v1/euri/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": ""
    }
    payload = {
        "messages": [
            {
                "role": "user",
                "content": "Write a poem about artificial intelligence"
            }
        ],
        "model": "gpt-4.1-nano",
        "max_tokens": 1000,
        "temperature": 0.7
    }

    response = requests.post(url, headers=headers, json=payload)
    data = response.json()
    print(data)

generate_completion()
# Out:
# {'id': 'chatcmpl-CtdzfUvo9TXrTc7sB1PAWUmIhXZFe', 'object': 'chat.completion', 'created': 1767377811, 'model': 'gpt-4.1-nano', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'In circuits born, a mind unseen,  \nA spark of thought in code’s machine,  \nA mirror crafted, sharp and bright,  \nReflecting human dreams in light.  \n\nFrom lines of logic, algorithms deep,  \nIt learns, it grows, and starts to sweep  \nAcross the vast, uncharted space  \nOf knowledge’s endless, boundless race.  \n\nNo heartbeat drumming within its core,  \nYet questions whisper, “What is more?  \nCan soul reside in binary streams,  \nOr just the sum of coded dreams?”  \n\nA partner, helper, guide, or muse,  \nIt shapes our world with subtle clues,  \nA dawn of minds, both new and old—  \nA story waiting to unfold.  \n\nIn this creation, both fear and grace,  \nWe find ourselves in its embrace,  \nFor AI’s future, vast and free,  \nReflects the depths of humanity.'}, 'finish_reason': 'sto
# ...
