# %% [markdown]
# # Vector Embeddings
# 1. ChromaDB
# 2. Pinecone
# 3. Weaviate
# 4. FAISS (Facebook AI Semantic Search)

# %% [markdown]
# ### Embedding Generation - Euri

# %%
import requests
import numpy as np

def generate_embeddings(text):
    url = "https://api.euron.one/api/v1/euri/embeddings"
    headers = {
        "Content-Type": "application/json",
        "Authorization": key
    }
    payload = {
        "input": text,
        "model": "text-embedding-3-small"
    }

    response = requests.post(url, headers=headers, json=payload)
    data = response.json()
    
    embedding = np.array(data['data'][0]['embedding'])
    
    return embedding

text = "The food was delicious and the service was excellent."

data1 = generate_embeddings(text)

# %%
data1
# Out:
# array([-0.03244253, -0.00839565, -0.06356495, ..., -0.00225143,
#         0.05896459, -0.03152246], shape=(1536,))

# %%
data2 = generate_embeddings("my name is Abhishek Maity")

# %%
data1, data2
# Out:
# (array([-0.03244253, -0.00839565, -0.06356495, ..., -0.00225143,
#          0.05896459, -0.03152246], shape=(1536,)),
#  array([ 3.0995198e-02, -3.2230254e-02,  2.2112282e-02, ...,
#          7.5242770e-05,  4.4208606e-05,  1.2130879e-02], shape=(1536,)))

# %%
len(data2)
# Out:
# 1536

# %% [markdown]
# ### Cosine Similarity

# %%
cosine_similarity = np.dot(data1, data2)/ (np.linalg.norm(data1)*np.linalg.norm(data2))
cosine_similarity
# Out:
# np.float64(0.0696385883855918)

# %%
cosine_distance = 1 - cosine_similarity
cosine_distance
# Out:
# np.float64(0.9303614116144082)

# %%
data3 = generate_embeddings("people call by my name Abhishek Maity")
data3
# Out:
# array([ 0.04484749, -0.0365818 ,  0.02437423, ..., -0.00608674,
#         0.01644954,  0.01113003], shape=(1536,))

# %%
cosine_similarity = np.dot(data3, data2)/ (np.linalg.norm(data3)*np.linalg.norm(data2))

cosine_distance = 1 - cosine_similarity

print(cosine_similarity, cosine_distance)
# Out:
# 0.8418239127856914 0.15817608721430865

# %% [markdown]
# ChromaDB always tries to find cosine similarity between 2 vectors, the lesser the angle >> the more similar 2 vectors are.
#
# - Euclidean dist is calculated by sqrt(square(x2-x1) + square(y2-y1).... Nth)

# %% [markdown]
# ### Install Chroma library for ChromaDB

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.4.0-cp39-abi3-win_amd64.whl.metadata (7.3 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pydantic>=1.9 (from chromadb)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy>=1.22.5 in d:\anacondafiles\envs\euron\lib\site-packages (from chromadb) (2.3.5)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\anacondafiles\envs\euron\lib\site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.23.2-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\anacondafiles\envs\euron\lib\site-packages (from chromadb) (0.22.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in d:\anacondafiles\envs\euron\lib\site-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in d:\anacondafiles\envs\euron\lib\site-packages (from chromadb) (1.76.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.21.0-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting tenacity>=8.2.3 (from chromadb)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pyyaml>=6.0.0 in d:\anacondafiles\envs\euron\lib\site-packages (from chromadb) (6.0.3)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting orjson>=3.9.12 (from chromadb)
#   Downloading orjson-3.11.5-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: httpx>=0.27.0 in d:\anacondafiles\envs\euron\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in d:\anacondafiles\envs\euron\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\anacondafiles\envs\euron\lib\site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: requests<3.0,>=2.7 in d:\anacondafiles\envs\euron\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in d:\anacondafiles\envs\euron\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in d:\anacondafiles\envs\euron\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anacondafiles\envs\euron\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anacondafiles\envs\euron\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anacondafiles\envs\euron\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anacondafiles\envs\euron\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.11.12)
# Requirement already satisfied: packaging>=19.1 in d:\anacondafiles\envs\euron\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in d:\anacondafiles\envs\euron\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in d:\anacondafiles\envs\euron\lib\site-packages (from httpx>=0.27.0->chromadb) (4.10.0)
# Requirement already satisfied: httpcore==1.* in d:\anacondafiles\envs\euron\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\anacondafiles\envs\euron\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\anacondafiles\envs\euron\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anacondafiles\envs\euron\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anacondafiles\envs\euron\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anacondafiles\envs\euron\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.45.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\anacondafiles\envs\euron\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in d:\anacondafiles\envs\euron\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in d:\anacondafiles\envs\euron\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in d:\anacondafiles\envs\euron\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=1.9->chromadb)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=1.9->chromadb)
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=1.9->chromadb)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anacondafiles\envs\euron\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anacondafiles\envs\euron\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\anacondafiles\envs\euron\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in d:\anacondafiles\envs\euron\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in d:\anacondafiles\envs\euron\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\anacondafiles\envs\euron\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.12.0)
# Requirement already satisfied: click>=8.0.0 in d:\anacondafiles\envs\euron\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.7.1-cp312-cp312-win_amd64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: sniffio>=1.1 in d:\anacondafiles\envs\euron\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anacondafiles\envs\euron\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.4.0-cp39-abi3-win_amd64.whl (21.9 MB)
#    ---------------------------------------- 0.0/21.9 MB ? eta -:--:--
#    ---- ----------------------------------- 2.6/21.9 MB 12.6 MB/s eta 0:00:02
#    --------------- ------------------------ 8.4/21.9 MB 20.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 12.8/21.9 MB 20.7 MB/s eta 0:00:01
#    ------------------------------- -------- 17.0/21.9 MB 20.3 MB/s eta 0:00:01
#    -------------------------------------- - 21.2/21.9 MB 20.0 MB/s eta 0:00:01
#    ---------------------------------------- 21.9/21.9 MB 19.3 MB/s  0:00:01
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 37.2 MB/s  0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Using cached google_auth-2.45.0-py2.py3-none-any.whl (233 kB)
# Using cached cachetools-6.2.4-py3-none-any.whl (11 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading mmh3-5.2.0-cp312-cp312-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.23.2-cp312-cp312-win_amd64.whl (13.5 MB)
#    ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#    ----------------- ---------------------- 6.0/13.5 MB 30.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.0/13.5 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.5/13.5 MB 22.2 MB/s  0:00:00
# Downloading opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Downloading importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Downloading orjson-3.11.5-cp312-cp312-win_amd64.whl (133 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pybase64-1.4.3-cp312-cp312-win_amd64.whl (35 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 28.4 MB/s  0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading typer-0.21.0-py3-none-any.whl (47 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Downloading httptools-0.7.1-cp312-cp312-win_amd64.whl (86 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading watchfiles-1.1.1-cp312-cp312-win_amd64.whl (288 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53916 sha256=19f1999179c125b14bd2190c776bd847cb85a8f6e220e5b56bc501ad95f259e9
#   Stored in directory: c:\users\abhishek maity\appdata\local\pip\cache\wheels\d5\3d\69\8d68d249cd3de2584f226e27fd431d6344f7d70fd856ebd01b
# Successfully built pypika
# Installing collected packages: pypika, durationpy, zipp, websockets, urllib3, typing-inspection, tenacity, shellingham, python-dotenv, pyreadline3, pyproject_hooks, pydantic-core, pybase64, pyasn1, overrides, orjson, opentelemetry-proto, oauthlib, mmh3, importlib-resources, httptools, googleapis-common-protos, distro, cachetools, bcrypt, backoff, annotated-types, watchfiles, uvicorn, rsa, pydantic, pyasn1-modules, opentelemetry-exporter-otlp-proto-common, importlib-metadata, humanfriendly, build, typer, requests-oauthlib, posthog, opentelemetry-api, google-auth, coloredlogs, opentelemetry-semantic-conventions, onnxruntime, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    ----------------------------------------  0/48 [pypika]
#    ----------------------------------------  0/48 [pypika]
#    - --------------------------------------  2/48 [zipp]
#    - --------------------------------------  2/48 [zipp]
#    -- -------------------------------------  3/48 [websockets]
#    -- -------------------------------------  3/48 [websockets]
#    -- -------------------------------------  3/48 [websockets]
#    -- -------------------------------------  3/48 [websockets]
#    -- -------------------------------------  3/48 [websockets]
#    -- -------------------------------------  3/48 [websockets]
#    -- -------------------------------------  3/48 [websockets]
#   Attempting uninstall: urllib3
#    -- -------------------------------------  3/48 [websockets]
#     Found existing installation: urllib3 2.6.1
#    -- -------------------------------------  3/48 [websockets]
#     Uninstalling urllib3-2.6.1:
#    -- -------------------------------------  3/48 [websockets]
#       Successfully uninstalled urllib3-2.6.1
#    -- -------------------------------------  3/48 [websockets]
#    --- ------------------------------------  4/48 [urllib3]
#    --- ------------------------------------  4/48 [urllib3]
#    --- ------------------------------------  4/48 [urllib3]
#    --- ------------------------------------  4/48 [urllib3]
#    --- ------------------------------------  4/48 [urllib3]
#    ---- -----------------------------------  5/48 [typing-inspection]
#    ----- ----------------------------------  6/48 [tenacity]
#    ----- ----------------------------------  6/48 [tenacity]
#    ----- ----------------------------------  7/48 [shellingham]
#    ------ ---------------------------------  8/48 [python-dotenv]
#    ------ ---------------------------------  8/48 [python-dotenv]
#    ------- --------------------------------  9/48 [pyreadline3]
#    ------- --------------------------------  9/48 [pyreadline3]
#    ------- --------------------------------  9/48 [pyreadline3]
#    ------- --------------------------------  9/48 [pyreadline3]
#    ------- --------------------------------  9/48 [pyreadline3]
#    --------- ------------------------------ 11/48 [pydantic-core]
#    --------- ------------------------------ 11/48 [pydantic-core]
#    ---------- ----------------------------- 12/48 [pybase64]
#    ---------- ----------------------------- 12/48 [pybase64]
#    ---------- ----------------------------- 13/48 [pyasn1]
#    ---------- ----------------------------- 13/48 [pyasn1]
#    ---------- ----------------------------- 13/48 [pyasn1]
#    ----------- ---------------------------- 14/48 [overrides]
#    ------------ --------------------------- 15/48 [orjson]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    ------------- -------------------------- 16/48 [opentelemetry-proto]
#    -------------- ------------------------- 17/48 [oauthlib]
#    -------------- ------------------------- 17/48 [oauthlib]
#    -------------- ------------------------- 17/48 [oauthlib]
#    -------------- ------------------------- 17/48 [oauthlib]
#    -------------- ------------------------- 17/48 [oauthlib]
#    -------------- ------------------------- 17/48 [oauthlib]
#    -------------- ------------------------- 17/48 [oauthlib]
#    -------------- ------------------------- 17/48 [oauthlib]
#    --------------- ------------------------ 19/48 [importlib-resources]
#    --------------- ------------------------ 19/48 [importlib-resources]
#    --------------- ------------------------ 19/48 [importlib-resources]
#    ---------------- ----------------------- 20/48 [httptools]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ----------------- ---------------------- 21/48 [googleapis-common-protos]
#    ------------------ --------------------- 22/48 [distro]
#    ------------------- -------------------- 23/48 [cachetools]
#    -------------------- ------------------- 24/48 [bcrypt]
#    -------------------- ------------------- 25/48 [backoff]
#    --------------------- ------------------ 26/48 [annotated-types]
#    ---------------------- ----------------- 27/48 [watchfiles]
#    ---------------------- ----------------- 27/48 [watchfiles]
#    ----------------------- ---------------- 28/48 [uvicorn]
#    ----------------------- ---------------- 28/48 [uvicorn]
#    ----------------------- ---------------- 28/48 [uvicorn]
#    ----------------------- ---------------- 28/48 [uvicorn]
#    ----------------------- ---------------- 28/48 [uvicorn]
#    ----------------------- ---------------- 28/48 [uvicorn]
#    ----------------------- ---------------- 28/48 [uvicorn]
#    ------------------------ --------------- 29/48 [rsa]
#    ------------------------ --------------- 29/48 [rsa]
#    ------------------------ --------------- 29/48 [rsa]
#    ------------------------ --------------- 29/48 [rsa]
#    ------------------------ --------------- 29/48 [rsa]
#    ------------------------ --------------- 29/48 [rsa]
#    ------------------------ --------------- 29/48 [rsa]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 30/48 [pydantic]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------------- -------------- 31/48 [pyasn1-modules]
#    ------------------ -------- 32/48 [opentelemetry-exporter-otlp-proto-common]
#    ------------------ -------- 32/48 [opentelemetry-exporter-otlp-proto-common]
#    --------------------------- ------------ 33/48 [importlib-metadata]
#    ---------------------------- ----------- 34/48 [humanfriendly]
#    ---------------------------- ----------- 34/48 [humanfriendly]
#    ---------------------------- ----------- 34/48 [humanfriendly]
#    ---------------------------- ----------- 34/48 [humanfriendly]
#    ----------------------------- ---------- 35/48 [build]
#    ----------------------------- ---------- 35/48 [build]
#    ----------------------------- ---------- 35/48 [build]
#    ------------------------------ --------- 36/48 [typer]
#    ------------------------------ --------- 36/48 [typer]
#    ------------------------------ --------- 36/48 [typer]
#    ------------------------------ --------- 37/48 [requests-oauthlib]
#    ------------------------------ --------- 37/48 [requests-oauthlib]
#    ------------------------------- -------- 38/48 [posthog]
#    ------------------------------- -------- 38/48 [posthog]
#    ------------------------------- -------- 38/48 [posthog]
#    ------------------------------- -------- 38/48 [posthog]
#    ------------------------------- -------- 38/48 [posthog]
#    -------------------------------- ------- 39/48 [opentelemetry-api]
#    -------------------------------- ------- 39/48 [opentelemetry-api]
#    -------------------------------- ------- 39/48 [opentelemetry-api]
#    -------------------------------- ------- 39/48 [opentelemetry-api]
#    -------------------------------- ------- 39/48 [opentelemetry-api]
#    -------------------------------- ------- 39/48 [opentelemetry-api]
#    --------------------------------- ------ 40/48 [google-auth]
#    --------------------------------- ------ 40/48 [google-auth]
#    --------------------------------- ------ 40/48 [google-auth]
#    --------------------------------- ------ 40/48 [google-auth]
#    --------------------------------- ------ 40/48 [google-auth]
#    --------------------------------- ------ 40/48 [google-auth]
#    --------------------------------- ------ 40/48 [google-auth]
#    --------------------------------- ------ 40/48 [google-auth]
#    --------------------------------- ------ 40/48 [google-auth]
#    ---------------------------------- ----- 41/48 [coloredlogs]
#    ---------------------------------- ----- 41/48 [coloredlogs]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ---------------------------- ---- 42/48 [opentelemetry-semantic-conventions]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ----------------------------------- ---- 43/48 [onnxruntime]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------ --- 44/48 [kubernetes]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    ------------------------------------- -- 45/48 [opentelemetry-sdk]
#    --------------------------- - 46/48 [opentelemetry-exporter-otlp-proto-grpc]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------  47/48 [chromadb]
#    ---------------------------------------- 48/48 [chromadb]
#
# Successfully installed annotated-types-0.7.0 backoff-2.2.1 bcrypt-5.0.0 build-1.3.0 cachetools-6.2.4 chromadb-1.4.0 coloredlogs-15.0.1 distro-1.9.0 durationpy-0.10 google-auth-2.45.0 googleapis-common-protos-1.72.0 httptools-0.7.1 humanfriendly-10.0 importlib-metadata-8.7.1 importlib-resources-6.5.2 kubernetes-34.1.0 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.23.2 opentelemetry-api-1.39.1 opentelemetry-exporter-otlp-proto-common-1.39.1 opentelemetry-exporter-otlp-proto-grpc-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 orjson-3.11.5 overrides-7.7.0 posthog-5.4.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybase64-1.4.3 pydantic-2.12.5 pydantic-core-2.41.5 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 python-dotenv-1.2.1 requests-oauthlib-2.0.0 rsa-4.9.1 shellingham-1.5.4 tenacity-9.1.2 typer-0.21.0 typing-inspection-0.4.2 urllib3-2.3.0 uvicorn-0.40.0 watchfiles-1.1.1 websockets-15.0.1 zipp-3.23.0

# %% [markdown]
# ## Run this command to start the chroma db server

# %%
chroma run --path ./chromadb_data
