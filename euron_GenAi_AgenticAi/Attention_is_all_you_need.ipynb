# %% [markdown]
# # Base Architecture of all LLM's - The Transformer model architecture

# %% [markdown]
# ![image.png](attachment:1b82538a-0fec-49b0-80a3-a4d51be9170e.png)

# %% [markdown]
# https://bbycroft.net/llm  - for visualization
